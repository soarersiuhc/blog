# %%
import tensorflow as tf
from tensorboard.plugins.hparams import api as hp
import matplotlib.pyplot as plt
import numpy as np

# %%
(X_train, y_train), (X_test, y_test) = tf.keras.datasets.cifar10.load_data()

# %%
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((50000, 32, 32, 3), (50000, 1), (10000, 32, 32, 3), (10000, 1))

# %%
X_train_normalized, X_test_normalized = X_train / 255.0, X_test / 255.0

# %% [markdown]
# ## Model

# %%
HP_NORMALIZE_INPUT = hp.HParam('normalize_input', hp.Discrete([True, False]))
HP_OPTIMIZER = hp.HParam('optimizer', hp.Discrete(['adam', 'sgd']))
HP_EPOCH = hp.HParam('epoch', hp.IntInterval(1, 5))
HP_L2_REGULARIZATION = hp.HParam('l2_regularization', hp.RealInterval(0.0, 0.1))

HPARAMS_LIST = [HP_NORMALIZE_INPUT, HP_OPTIMIZER, HP_EPOCH, HP_L2_REGULARIZATION]

METRIC_ACCURACY = 'accuracy'

TF_LOGDIR = "logs/cs231n_softmax_hparam_tuning"

with tf.summary.create_file_writer(TF_LOGDIR).as_default():
    hp.hparams_config(
      hparams=HPARAMS_LIST,
      metrics=[hp.Metric(METRIC_ACCURACY, display_name='Accuracy')],
    )

# %%
def train_and_evaluate_model(hparams):
    if hparams[HP_NORMALIZE_INPUT]:
        X_train_processed, X_test_processed = X_train_normalized, X_test_normalized
    else:
        X_train_processed, X_test_processed = X_train, X_test
        
    model = tf.keras.models.Sequential([
        tf.keras.layers.Flatten(input_shape=(32, 32, 3)),
        tf.keras.layers.Dense(
            10, 
            activation="softmax", 
            kernel_regularizer=tf.keras.regularizers.l2(hparams[HP_L2_REGULARIZATION])
        ),
    ])
    
    model.compile(
        optimizer=hparams[HP_OPTIMIZER],
        loss="sparse_categorical_crossentropy",
        metrics=[METRIC_ACCURACY]
    )
    
    model.fit(X_train_processed, y_train, epochs=hparams[HP_EPOCH])
    
    _, accuracy = model.evaluate(X_test_processed, y_test, verbose=True)
    
    return accuracy

# %%
def run(run_dir, hparams):
    # clear directory
    # !rm -rf $TF_LOGDIR
    
    with tf.summary.create_file_writer(run_dir).as_default():
        hp.hparams(hparams)  # record the values used in this trial
        accuracy = train_and_evaluate_model(hparams)
        tf.summary.scalar(METRIC_ACCURACY, accuracy, step=1)

# %%
session_num = 0

for normalize_input in HP_NORMALIZE_INPUT.domain.values:
    for optimizer in HP_OPTIMIZER.domain.values:
        for epoch in range(HP_EPOCH.domain.min_value, HP_EPOCH.domain.max_value):
            for l2_regularization in (HP_L2_REGULARIZATION.domain.min_value, HP_L2_REGULARIZATION.domain.max_value):
                hparams = {
                    HP_NORMALIZE_INPUT: normalize_input,
                    HP_OPTIMIZER: optimizer,
                    HP_EPOCH: epoch,
                    HP_L2_REGULARIZATION: l2_regularization,
                }

                run_name = "run-%d" % session_num
                print('--- Starting trial: %s' % run_name)
                print({h.name: hparams[h] for h in hparams})
                run(TF_LOGDIR + "/" + run_name, hparams)
                session_num += 1
# Out:
# --- Starting trial: run-0
# {'normalize_input': False, 'optimizer': 'adam', 'epoch': 1, 'l2_regularization': 0.0}
# 1563/1563 [==============================] - 6s 4ms/step - loss: 101.7485 - accuracy: 0.2374
# 313/313 [==============================] - 2s 5ms/step - loss: 90.6113 - accuracy: 0.2526
# --- Starting trial: run-1
# {'normalize_input': False, 'optimizer': 'adam', 'epoch': 1, 'l2_regularization': 0.1}
# 1563/1563 [==============================] - 6s 4ms/step - loss: 101.0510 - accuracy: 0.2339
# 313/313 [==============================] - 0s 2ms/step - loss: 93.5108 - accuracy: 0.2870
# --- Starting trial: run-2
# {'normalize_input': False, 'optimizer': 'adam', 'epoch': 2, 'l2_regularization': 0.0}
# Epoch 1/2
# 1563/1563 [==============================] - 3s 2ms/step - loss: 97.3508 - accuracy: 0.2380
# Epoch 2/2
# 1563/1563 [==============================] - 3s 2ms/step - loss: 86.1512 - accuracy: 0.2590
# 313/313 [==============================] - 1s 2ms/step - loss: 108.3354 - accuracy: 0.2179: 0s - loss: 108.1394 - accuracy: 0.21
# --- Starting trial: run-3
# {'normalize_input': False, 'optimizer': 'adam', 'epoch': 2, 'l2_regularization': 0.1}
# Epoch 1/2
# 1563/1563 [==============================] - 3s 2ms/step - loss: 98.2433 - accuracy: 0.2342
# Epoch 2/2
# 1563/1563 [==============================] - 5s 3ms/step - loss: 89.0812 - accuracy: 0.2588
# 313/313 [==============================] - 0s 2ms/step - loss: 115.4211 - accuracy: 0.2445
# --- Starting trial: run-4
# {'normalize_input': False, 'optimizer': 'adam', 'epoch': 3, 'l2_regularization': 0.0}
# Epoch 1/3
# 1563/1563 [==============================] - 3s 2ms/step - loss: 98.9673 - accuracy: 0.2372
# Epoch 2/3
# 1563/1563 [==============================] - 3s 2ms/step - loss: 87.0928 - accuracy: 0.2588
# Epoch 3/3
# 1563/1563 [==============================] - 3s 2ms/step - loss: 85.5992 - accuracy: 0.2659
# 313/313 [==============================] - 0s 2ms/step - loss: 86.2374 - accuracy: 0.2873
# --- Starting trial: run-5
# {'normalize_input': False, 'optimizer': 'adam', 'epoch': 3, 'l2_regularization': 0.1}
# Epoch 1/3
# 1563/1563 [==============================] - 4s 3ms/step - loss: 100.6899 - accuracy: 0.2379
# Epoch 2/3
# 1563/1563 [==============================] - 4s 3ms/step - loss: 91.1283 - accuracy: 0.2594
# Epoch 3/3
# 1563/1563 [==============================] - 3s 2ms/step - loss: 88.4636 - accuracy: 0.2660
# 313/313 [==============================] - 0s 2ms/step - loss: 97.8799 - accuracy: 0.2693A: 0s - loss: 96.9277 - accuracy:
# --- Starting trial: run-6
# {'normalize_input': False, 'optimizer': 'adam', 'epoch': 4, 'l2_regularization': 0.0}
# Epoch 1/4
# 1563/1563 [==============================] - 5s 3ms/step - loss: 99.9475 - accuracy: 0.2371
# Epoch 2/4
# 1563/1563 [==============================] - 3s 2ms/step - loss: 85.9442 - accuracy: 0.2611
# Epoch 3/4
# 1563/1563 [==============================] - 3s 2ms/step - loss: 84.5694 - accuracy: 0.2661
# Epoch 4/4
# 1563/1563 [==============================] - 3s 2ms/step - loss: 84.8684 - accuracy: 0.2725
# 313/313 [==============================] - 0s 1ms/step - loss: 97.3891 - accuracy: 0.2934
# --- Starting trial: run-7
# {'normalize_input': False, 'optimizer': 'adam', 'epoch': 4, 'l2_regularization': 0.1}
# Epoch 1/4
# 1563/1563 [==============================] - 3s 2ms/step - loss: 96.8927 - accuracy: 0.2374
# Epoch 2/4
# 1563/1563 [==============================] - 3s 2ms/step - loss: 87.2102 - accuracy: 0.2579
# Epoch 3/4
# 1563/1563 [==============================] - 3s 2ms/step - loss: 84.3527 - accuracy: 0.2691A: 3s - loss: 91.2164 - ET
# Epoch 4/4
# 1563/1563 [==============================] - 3s 2ms/step - loss: 87.2356 - accuracy: 0.2683
# 313/313 [==============================] - 0s 1ms/step - loss: 81.7949 - accuracy: 0.2229
# --- Starting trial: run-8
# {'normalize_input': False, 'optimizer': 'sgd', 'epoch': 1, 'l2_regularization': 0.0}
# 1563/1563 [==============================] - 3s 2ms/step - loss: 84499.2578 - accuracy: 0.2141
# 313/313 [==============================] - 0s 2ms/step - loss: 48527.3906 - accuracy: 0.2379: 0s - loss: 48389.6719 - accuracy:
# --- Starting trial: run-9
# {'normalize_input': False, 'optimizer': 'sgd', 'epoch': 1, 'l2_regularization': 0.1}
# 1563/1563 [==============================] - 3s 2ms/step - loss: 101219.5234 - accuracy: 0.1884A: 1s
# 313/313 [==============================] - 0s 1ms/step - loss: 102805.8438 - accuracy: 0.2267
# --- Starting trial: run-10
# {'normalize_input': False, 'optimizer': 'sgd', 'epoch': 2, 'l2_regularization': 0.0}
# Epoch 1/2
# 1563/1563 [==============================] - 4s 2ms/step - loss: 84056.6562 - accuracy: 0.2133
# Epoch 2/2
# 1563/1563 [==============================] - 3s 2ms/step - loss: 72873.8594 - accuracy: 0.2408
# 313/313 [==============================] - 1s 2ms/step - loss: 105760.3125 - accuracy: 0.1774
# --- Starting trial: run-11
# {'normalize_input': False, 'optimizer': 'sgd', 'epoch': 2, 'l2_regularization': 0.1}
# Epoch 1/2
# 1563/1563 [==============================] - 3s 2ms/step - loss: 100967.5156 - accuracy: 0.1847
# Epoch 2/2
# 1563/1563 [==============================] - 4s 2ms/step - loss: 97869.3516 - accuracy: 0.1930
# 313/313 [==============================] - 1s 2ms/step - loss: 112445.9531 - accuracy: 0.1365
# --- Starting trial: run-12
# {'normalize_input': False, 'optimizer': 'sgd', 'epoch': 3, 'l2_regularization': 0.0}
# Epoch 1/3
# 1563/1563 [==============================] - 3s 2ms/step - loss: 84100.6641 - accuracy: 0.2157
# Epoch 2/3
# 1563/1563 [==============================] - 3s 2ms/step - loss: 73218.5469 - accuracy: 0.2412: 0s - loss: 73144.2031 - accuracy: 0.24
# Epoch 3/3
# 1563/1563 [==============================] - 3s 2ms/step - loss: 70461.3438 - accuracy: 0.2505
# 313/313 [==============================] - 0s 1ms/step - loss: 66507.5938 - accuracy: 0.2537
# --- Starting trial: run-13
# {'normalize_input': False, 'optimizer': 'sgd', 'epoch': 3, 'l2_regularization': 0.1}
# Epoch 1/3
# 1563/1563 [==============================] - 3s 2ms/step - loss: 101459.8359 - accuracy: 0.1858
# Epoch 2/3
# 1563/1563 [==============================] - 4s 2ms/step - loss: 96802.8125 - accuracy: 0.1952
# Epoch 3/3
# 1563/1563 [==============================] - 3s 2ms/step - loss: 97136.7422 - accuracy: 0.1942
# 313/313 [==============================] - 0s 1ms/step - loss: 77338.5625 - accuracy: 0.1825
# --- Starting trial: run-14
# {'normalize_input': False, 'optimizer': 'sgd', 'epoch': 4, 'l2_regularization': 0.0}
# Epoch 1/4
# 1563/1563 [==============================] - 3s 2ms/step - loss: 84203.2500 - accuracy: 0.2129
# Epoch 2/4
# 1563/1563 [==============================] - 3s 2ms/step - loss: 72904.7891 - accuracy: 0.2371
# Epoch 3/4
# 1563/1563 [==============================] - 3s 2ms/step - loss: 69457.5469 - accuracy: 0.2513
# Epoch 4/4
# 1563/1563 [==============================] - 3s 2ms/step - loss: 69201.1094 - accuracy: 0.2541
# 313/313 [==============================] - 0s 1ms/step - loss: 61989.3125 - accuracy: 0.2021
# --- Starting trial: run-15
# {'normalize_input': False, 'optimizer': 'sgd', 'epoch': 4, 'l2_regularization': 0.1}
# Epoch 1/4
# 1563/1563 [==============================] - 3s 2ms/step - loss: 101637.3125 - accuracy: 0.1856
# Epoch 2/4
# 1563/1563 [==============================] - 3s 2ms/step - loss: 96207.4297 - accuracy: 0.1954
# Epoch 3/4
# 1563/1563 [==============================] - 3s 2ms/step - loss: 97448.4453 - accuracy: 0.1926
# Epoch 4/4
# 1563/1563 [==============================] - 3s 2ms/step - loss: 96274.2344 - accuracy: 0.1977
# 313/313 [==============================] - 0s 1ms/step - loss: 71893.8516 - accuracy: 0.1862
# --- Starting trial: run-16
# {'normalize_input': True, 'optimizer': 'adam', 'epoch': 1, 'l2_regularization': 0.0}
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.9577 - accuracy: 0.3164
# 313/313 [==============================] - 1s 2ms/step - loss: 1.8867 - accuracy: 0.3385
# --- Starting trial: run-17
# {'normalize_input': True, 'optimizer': 'adam', 'epoch': 1, 'l2_regularization': 0.1}
# 1563/1563 [==============================] - 5s 3ms/step - loss: 2.2794 - accuracy: 0.2717
# 313/313 [==============================] - 1s 2ms/step - loss: 2.2284 - accuracy: 0.3134
# --- Starting trial: run-18
# {'normalize_input': True, 'optimizer': 'adam', 'epoch': 2, 'l2_regularization': 0.0}
# Epoch 1/2
# 1563/1563 [==============================] - 9s 6ms/step - loss: 1.9763 - accuracy: 0.3142
# Epoch 2/2
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.8784 - accuracy: 0.3511
# 313/313 [==============================] - 2s 5ms/step - loss: 1.8303 - accuracy: 0.3601
# --- Starting trial: run-19
# {'normalize_input': True, 'optimizer': 'adam', 'epoch': 2, 'l2_regularization': 0.1}
# Epoch 1/2
# 1563/1563 [==============================] - 5s 3ms/step - loss: 2.2780 - accuracy: 0.2739
# Epoch 2/2
# 1563/1563 [==============================] - 4s 2ms/step - loss: 2.1433 - accuracy: 0.2795
# 313/313 [==============================] - 1s 2ms/step - loss: 2.0992 - accuracy: 0.2816
# --- Starting trial: run-20
# {'normalize_input': True, 'optimizer': 'adam', 'epoch': 3, 'l2_regularization': 0.0}
# Epoch 1/3
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.9672 - accuracy: 0.3158
# Epoch 2/3
# 1563/1563 [==============================] - 4s 3ms/step - loss: 1.8754 - accuracy: 0.3546
# Epoch 3/3
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.8523 - accuracy: 0.3648
# 313/313 [==============================] - 0s 2ms/step - loss: 1.9523 - accuracy: 0.3475
# --- Starting trial: run-21
# {'normalize_input': True, 'optimizer': 'adam', 'epoch': 3, 'l2_regularization': 0.1}
# Epoch 1/3
# 1563/1563 [==============================] - 3s 2ms/step - loss: 2.2824 - accuracy: 0.2688
# Epoch 2/3
# 1563/1563 [==============================] - 3s 2ms/step - loss: 2.1374 - accuracy: 0.2815
# Epoch 3/3
# 1563/1563 [==============================] - 3s 2ms/step - loss: 2.1475 - accuracy: 0.2777: 0s - loss: 2.1485 - accu
# 313/313 [==============================] - 0s 1ms/step - loss: 2.0708 - accuracy: 0.3100
# --- Starting trial: run-22
# {'normalize_input': True, 'optimizer': 'adam', 'epoch': 4, 'l2_regularization': 0.0}
# Epoch 1/4
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.9678 - accuracy: 0.3162
# Epoch 2/4
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.8881 - accuracy: 0.3477
# Epoch 3/4
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.8596 - accuracy: 0.3635
# Epoch 4/4
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.8459 - accuracy: 0.3692
# 313/313 [==============================] - 0s 2ms/step - loss: 1.9460 - accuracy: 0.3369
# --- Starting trial: run-23
# {'normalize_input': True, 'optimizer': 'adam', 'epoch': 4, 'l2_regularization': 0.1}
# Epoch 1/4
# 1563/1563 [==============================] - 4s 3ms/step - loss: 2.2745 - accuracy: 0.2704
# Epoch 2/4
# 1563/1563 [==============================] - 3s 2ms/step - loss: 2.1452 - accuracy: 0.2770
# Epoch 3/4
# 1563/1563 [==============================] - 5s 3ms/step - loss: 2.1473 - accuracy: 0.2776
# Epoch 4/4
# 1563/1563 [==============================] - 3s 2ms/step - loss: 2.1303 - accuracy: 0.2815
# 313/313 [==============================] - 1s 2ms/step - loss: 2.1548 - accuracy: 0.2933
# --- Starting trial: run-24
# {'normalize_input': True, 'optimizer': 'sgd', 'epoch': 1, 'l2_regularization': 0.0}
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.9472 - accuracy: 0.3049
# 313/313 [==============================] - 1s 2ms/step - loss: 1.9923 - accuracy: 0.3008
# --- Starting trial: run-25
# {'normalize_input': True, 'optimizer': 'sgd', 'epoch': 1, 'l2_regularization': 0.1}
# 1563/1563 [==============================] - 6s 4ms/step - loss: 2.3998 - accuracy: 0.2758
# 313/313 [==============================] - 1s 2ms/step - loss: 2.1398 - accuracy: 0.2599
# --- Starting trial: run-26
# {'normalize_input': True, 'optimizer': 'sgd', 'epoch': 2, 'l2_regularization': 0.0}
# Epoch 1/2
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.9441 - accuracy: 0.3068
# Epoch 2/2
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.8408 - accuracy: 0.3534
# 313/313 [==============================] - 0s 2ms/step - loss: 1.9858 - accuracy: 0.3090
# --- Starting trial: run-27
# {'normalize_input': True, 'optimizer': 'sgd', 'epoch': 2, 'l2_regularization': 0.1}
# Epoch 1/2
# 1563/1563 [==============================] - 4s 3ms/step - loss: 2.3995 - accuracy: 0.2760
# Epoch 2/2
# 1563/1563 [==============================] - 6s 4ms/step - loss: 2.0621 - accuracy: 0.2946
# 313/313 [==============================] - 0s 2ms/step - loss: 2.0339 - accuracy: 0.3253: 0s - loss: 2.0389 - accuracy:
# --- Starting trial: run-28
# {'normalize_input': True, 'optimizer': 'sgd', 'epoch': 3, 'l2_regularization': 0.0}
# Epoch 1/3
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.9487 - accuracy: 0.3059
# Epoch 2/3
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.8433 - accuracy: 0.3544
# Epoch 3/3
# 1563/1563 [==============================] - 4s 2ms/step - loss: 1.8155 - accuracy: 0.3602
# 313/313 [==============================] - 1s 3ms/step - loss: 1.7873 - accuracy: 0.3790
# --- Starting trial: run-29
# {'normalize_input': True, 'optimizer': 'sgd', 'epoch': 3, 'l2_regularization': 0.1}
# Epoch 1/3
# 1563/1563 [==============================] - 5s 3ms/step - loss: 2.3997 - accuracy: 0.2773
# Epoch 2/3
# 1563/1563 [==============================] - 4s 2ms/step - loss: 2.0610 - accuracy: 0.2938
# Epoch 3/3
# 1563/1563 [==============================] - 3s 2ms/step - loss: 2.0594 - accuracy: 0.2950
# 313/313 [==============================] - 1s 2ms/step - loss: 2.1263 - accuracy: 0.2582
# --- Starting trial: run-30
# {'normalize_input': True, 'optimizer': 'sgd', 'epoch': 4, 'l2_regularization': 0.0}
# Epoch 1/4
# 1563/1563 [==============================] - 4s 3ms/step - loss: 1.9498 - accuracy: 0.3048
# Epoch 2/4
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.8441 - accuracy: 0.3504
# Epoch 3/4
# 1563/1563 [==============================] - 4s 3ms/step - loss: 1.8137 - accuracy: 0.3656
# Epoch 4/4
# 1563/1563 [==============================] - 4s 2ms/step - loss: 1.7934 - accuracy: 0.3742
# 313/313 [==============================] - 1s 2ms/step - loss: 1.7934 - accuracy: 0.3690
# --- Starting trial: run-31
# {'normalize_input': True, 'optimizer': 'sgd', 'epoch': 4, 'l2_regularization': 0.1}
# Epoch 1/4
# 1563/1563 [==============================] - 5s 3ms/step - loss: 2.3959 - accuracy: 0.2770
# Epoch 2/4
# 1563/1563 [==============================] - 4s 2ms/step - loss: 2.0604 - accuracy: 0.2987
# Epoch 3/4
# 1563/1563 [==============================] - 4s 2ms/step - loss: 2.0606 - accuracy: 0.2954
# Epoch 4/4
# 1563/1563 [==============================] - 4s 3ms/step - loss: 2.0580 - accuracy: 0.2991
# 313/313 [==============================] - 1s 2ms/step - loss: 2.0273 - accuracy: 0.3138

# %% [markdown]
# ## Analysis

# %%
# %load_ext tensorboard

# %%
# %tensorboard --logdir $TF_LOGDIR
# Out:
#       <iframe id="tensorboard-frame-1936b21a57bf5c02" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-1936b21a57bf5c02");
#           const url = new URL("/", window.location);
#           url.port = 6006;
#           frame.src = url;
#         })();
#       </script>
